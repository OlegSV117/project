# %% [markdown]
# <a href="https://colab.research.google.com/github/OlegSV117/project/blob/dev-kraken/%D0%9B%D0%B8%D0%BD%D0%90%D0%BB%D0%B31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# __1.__ Исследовать на линейную зависимость:
#
# $$f_{1}(x)=e^{x}, f_{2}(x)=1, f_{3}(x)=x+1, f_{4}(x)=x-e^{x}.$$

# %% [markdown]
# ##Решение: $$f_{4}(x)=x-e^{x} =  f_{3}-f_{2}-f_{1}.$$
# Ответ: Функции линейно зависимы.

# %% [markdown]
# __2.__ Исследовать на линейную зависимость:
# $$f_{1}(x)=2, f_{2}(x)=x, f_{3}(x)=x^{2}, f_{4}(x)=(x+1)^{2}$$

# %% [markdown]
# ##Решение: $$f_{4}(x)= f_{3}+ 2\cdot f_{2}+f_{1}.$$
# Ответ: Функции линейно зависимы.

# %% [markdown]
# __3.__ Найти координаты вектора $x = (2, 3, 5)\in \mathbb{R}^{3}$ в базисе $b_{1}=(0, 0, 10)$, $b_{2}=(2, 0, 0)$, $b_{3}=(0, 1, 0)$.

# %% [markdown]
# ##Решение:
#
# $$x=(2, 3, 5)=(2,0,0)+(0, 3, 0)+(0, 0, 5)=1/2\cdot(0, 0, 10)+1\cdot(2, 0, 0)+3\cdot(0, 1, 0)=1/2b_{1}+b_{2}+3e_{3},$$
#
#
# то есть координатами вектора $x$ в  базисе  являются $1/2$, $1$, $3$.

# %% [markdown]
# ##__4.__ Найти координаты вектора $3x^{2}-2x+2\in\mathbb{R}^{3}[x]$:
#
# а) в базисе $1$, $x$, $x^{2}$;
#
# ##Решение: координатами вектора в  базисе $1$, $x$, $x^{2}$  являются $2$, $-2$, $3$.
#
# б) в базисе $x^{2}$, $x-1$, $1$.
#
# ##Решение: координатами вектора в  базисе $x^{2}$, $x-1$, $1$ являются $3$, $-2$, $0$.

# %% [markdown]
# ##__5.__ Установить, является ли линейным подпространством:
#
# а) совокупность всех векторов трехмерного пространства, у которых по крайней мере одна из первых двух координат равна нулю;
# Решение: вектор суммы (0,1,1)+(1,0,1) = (1, 1, 2) не принадлежит исходной совокупности.
#
#  ## Ответ.подпространством  не является.
#
# б) все векторы, являющиеся линейными комбинациями данных векторов $\{u_{1}, u_{2}, \ldots, u_{n}\}$.
#
# ## Ответ: Является подпространством по определению.

# %% [markdown]
# __1.__ Найти скалярное произведение векторов $x, y \in \mathbb{R}$:<br>
# а) $x=(0,-3, 6),~y=(-4, 7, 9);$<br>
#  ## Решение: (x,y) = -21+54 = 33
#
#
# б) $x=(7, -4, 0, 1),~y=(-3, 1, 11, 2).$
#  ## Решение: (x,y) = -21-4+2=-23
# __2.__ Найти нормы векторов $(4, 2, 4)$ и $(12, 3, 4)$ и угол между ними.
#
# $$ \left \|x\right \| = (16+4+16)^{1/2} = 6 $$
#
# $$ \left \|y\right \| = (144+9+16)^{1/2} = 13 $$
#
# (x, y) = 48+6+16 = 70
#
# $$cos\varphi = \frac{70}{6 \cdot 13}\approx 0.9$$
#
# __3.__ Будет ли линейное пространство евклидовым, если за скалярное произведение принять:<br>
# а) произведение длин векторов;<br>
# НЕТ, так как не выполняется 3) $(x_{1}+x_{2},y)=(x_{1},y)+(x_{2},y);$<br>
# $|x_{1}+x_{2}|\neq |x_{1}| + |x_{2}|;$
#
# б) утроенное обычное скалярное произведение векторов?<br>
#
# Да, все аксиомы евклидова пространства выполнимы
#
# __4.__ Какие из нижеперечисленных векторов образуют ортонормированный базис в линейном пространстве $\mathbb{R}^{3}$:<br>
# а) $(1,0,0),(0,0,1);$ <br>
# Да, все аксиомы выполнимы!
#
# б) $(1/\sqrt{2},-1/\sqrt{2},0),(1/\sqrt{2},1/\sqrt{2},0), (0,0,1);$<br>
# Да, все аксиомы евклидова пространства выполнимы
#
# в) $(1/2, -1/2, 0), (0, 1/2, 1/2), (0,0,1);$<br>
# НЕТ $||(1/2, -1/2, 0)||= (1/2)^{1/2} \neq 1$<br>
#
# г) $(1,0,0),(0,1,0),(0,0,1)?$
# Да, все аксиомы евклидова пространства выполнимы
